# %%
spot = pd.read_csv("../DATA/raw/nifty_spot_5min.csv", parse_dates=["timestamp"])
fut  = pd.read_csv("../DATA/raw/nifty_futures_5min.csv", parse_dates=["timestamp"])
opt  = pd.read_csv("../DATA/raw/nifty_options_5min.csv", parse_dates=["timestamp"])

spot.dropna(inplace=True)
fut.dropna(inplace=True)
opt.dropna(inplace=True)
